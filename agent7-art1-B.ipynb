# %%
# File: art_openings_brooklyn.py
from browser_use import Agent, ChatGoogle
from dotenv import load_dotenv
import os
import asyncio
import json
from datetime import datetime

# ===============================
# Setup
# ===============================

load_dotenv()
llm = ChatGoogle(model="gemini-2.5-flash")

# ===============================
# Gallery Sources
# ===============================

sources = [
    # 🖼 Bushwick
    "https://www.tigerstrikesasteroid.com/brooklyn",     # Tiger Strikes Asteroid
    "https://www.bushwickgallery.com",                   # Bushwick Gallery
    "https://www.brooklynartcave.com/events",            # Brooklyn Art Cave
    "https://carvalhopark.com/exhibitions",              # Carvalho Park
    "https://www.the-living-gallery.com/events",         # The Living Gallery
    "http://www.transmitter.nyc/",                      # Transmitter
    "https://www.activespacestudios.com/gallery",        # Active Space Studios Gallery

    # 🎨 Williamsburg
    "https://www.amant.org/exhibitions",                 # Amant
    "https://www.brooklyncc.com/dog-house-gallery",      # Dog House Gallery
    "https://awitanewyorkartmag.squarespace.com/announcements",  #awita
    "https://miriamgallery.com/",                       # miriam     
     # Awita New York Studio

    # 🌀 Ridgewood
    "https://www.tempestonweirfield.com/",               # Tempest (Ridgewood)
    "https://www.lorimoto.com/exhibitions",              # Lorimoto Gallery

    # 🌸 Maspeth
    "https://www.mrsgallery.com/exhibitions"             # Mrs. Gallery
]

visited_sources_file = "visited_galleries.json"
markdown_path = "brooklyn_openings_summary.md"
structured_path = "brooklyn_openings_data.json"

# ===============================
# Helpers
# ===============================

def load_visited_sources():
    if os.path.exists(visited_sources_file):
        with open(visited_sources_file, "r", encoding="utf-8") as f:
            return set(json.load(f))
    return set()

def save_visited_sources(visited):
    with open(visited_sources_file, "w", encoding="utf-8") as f:
        json.dump(list(visited), f, indent=2)

def get_remaining_sources():
    visited = load_visited_sources()
    return [s for s in sources if s not in visited]

def append_markdown(new_text, path=markdown_path):
    with open(path, "a", encoding="utf-8") as f:
        f.write("\n\n---\n\n")
        f.write(new_text)

def append_structured(new_data, path=structured_path):
    if os.path.exists(path):
        with open(path, "r", encoding="utf-8") as f:
            existing = json.load(f)
    else:
        existing = []

    if isinstance(new_data, str):
        try:
            new_data = json.loads(new_data)
        except:
            new_data = [{"raw": new_data}]

    combined = existing + new_data
    with open(path, "w", encoding="utf-8") as f:
        json.dump(combined, f, indent=2)

# ===============================
# Agent Setup
# ===============================

def make_agent(remaining_sources):
    return Agent(
        task=(
            "Find the next exhibition opening or event for each listed art gallery "
            "in Bushwick, Williamsburg, Ridgewood, or Maspeth. "
            "Extract the event title, opening date, opening time, and if available, "
            "the exhibiting artist(s) or show theme. "
            "Ignore past exhibitions — only include future or current openings with 2025 dates. "
            "Return results as both a clean markdown summary and a structured JSON array "
            "with fields: gallery_name, address (if visible), event_name, opening_date, "
            "opening_time, artist, source_url. "
            f"Restrict browsing to these sites: {', '.join(remaining_sources)}."
        ),
        llm=llm,
        browser_config={
            "headless": True,
            "browser_type": "chromium",
            "browser_timeout": 90,
            "viewport_size": {"width": 1280, "height": 720},
            "extra_chromium_args": [
                "--no-sandbox",
                "--disable-dev-shm-usage",
                "--disable-gpu",
            ]
        }
    )

# ===============================
# Main Run
# ===============================

async def run_openings(batch_size=3):
    visited = load_visited_sources()
    remaining = get_remaining_sources()

    if not remaining:
        print("✅ All galleries already checked.")
        return

    next_batch = remaining[:batch_size]
    print(f"🎨 Checking galleries: {', '.join(next_batch)}")

    agent = make_agent(next_batch)

    try:
        history = await asyncio.wait_for(agent.run(max_steps=25), timeout=300)
    except asyncio.TimeoutError:
        print("❌ Agent timed out")
        return

    final_result = history.final_result()
    if final_result:
        append_markdown(f"## Gallery Batch ({', '.join(next_batch)})\n\n{final_result}")

        if hasattr(history, "structured_output") and history.structured_output:
            append_structured(history.structured_output)

        print(f"✅ Results from {next_batch} saved.")
    else:
        print("⚠️ No final result produced.")

    visited.update(next_batch)
    save_visited_sources(visited)

# ===============================
# Manual Execution
# ===============================

if __name__ == "__main__":
    # For Jupyter notebooks, use await directly instead of asyncio.run()
    try:
        get_ipython()  # This will succeed in Jupyter/IPython
        # We're in a notebook - the user should run: await run_openings()
        print("\n⚠️  Running in Jupyter notebook detected!")
        print("📝 Please run this command in a new cell:")
        print("   await run_openings()")
    except NameError:
        # Not in Jupyter - use asyncio.run()
        asyncio.run(run_openings())
# Out:
# ⚠️  Running in Jupyter notebook detected!
# 📝 Please run this command in a new cell:
#    await run_openings()

# %%
await run_openings()
# Out:
# 🎨 Checking galleries: https://www.tigerstrikesasteroid.com/brooklyn, https://www.bushwickgallery.com, https://www.brooklynartcave.com/events
# INFO     [service] Using anonymized telemetry, see https://docs.browser-use.com/development/telemetry.
# INFO     [Agent] 🚀 Task: Find the next exhibition opening or event for each listed art gallery in Bushwick, Williamsburg, Ridgewood, or Maspeth. Extract the event title, opening date, opening time, and if available, the exhibiting artist(s) or show theme. Ignore past exhibitions — only include future or current openings with 2025 dates. Return results as both a clean markdown summary and a structured JSON array with fields: gallery_name, address (if visible), event_name, opening_date, opening_time, artist, source_url. Restrict browsing to these sites: https://www.tigerstrikesasteroid.com/brooklyn, https://www.bushwickgallery.com, https://www.brooklynartcave.com/events.
# /opt/homebrew/Caskroom/miniforge/base/envs/browz1/lib/python3.12/concurrent/futures/thread.py:165: RuntimeWarning: coroutine 'run_openings' was never awaited
#   def submit(self, fn, /, *args, **kwargs):
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# INFO     [Agent] 🧠 Starting a browser-use version 0.7.3 with model=gemini-2.5-flash
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 1:
# INFO     [Agent]   👍 Eval: The previous goal was to start the task. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Create a `todo.md` file with a detailed plan for visiting each website, extracting event information, and formatting the output as requested by the user.
# INFO     [Agent]   🦾 [ACTION 1/1] write_file: file_name: todo.md, content: # Art Gallery Exhibition Collection Task\n\n## Goal: Find next exhibition opening...
# INFO     [tools] 💾 Data written to file todo.md successfully.
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 2:
# INFO     [Agent]   👍 Eval: Successfully created the todo.md file. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Initialize `events.json` and `results.md` files with empty content, then mark the first task in `todo.md` as complete.
# INFO     [Agent]   🦾 [ACTION 1/3] write_file: file_name: events.json, content: [], append: False, trailing_newline: False, leading_newline: False
# INFO     [tools] 💾 Data written to file events.json successfully.
# INFO     [Agent]   🦾 [ACTION 2/3] write_file: file_name: results.md, content: # Art Gallery Exhibition Collection Results\n\n, append: False, trailing_newline
# INFO     [tools] 💾 Data written to file results.md successfully.
# INFO     [Agent]   🦾 [ACTION 3/3] replace_file_str: file_name: todo.md, old_str: - [ ] Initialize `events.json` and `results.md` files., new_str: - [x] Initial
# INFO     [tools] 💾 Successfully replaced all occurrences of "- [ ] Initialize `events.json` and `results.md` files." with "- [x] Initialize `events.json` and `results.md` files." in file todo.md
# INFO     [auth] ────────────────────────────────────────
# INFO     [auth] 🌐  View the details of this run in Browser Use Cloud:
# INFO     [auth]     👉  https://cloud.browser-use.com/hotlink?user_code=6YHAGPW72B55ZUAL
# INFO     [auth] ────────────────────────────────────────
#
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 3:
# INFO     [Agent]   👍 Eval: Successfully initialized `events.json` and `results.md` files and marked the task in `todo.md` as complete. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Navigate to the first gallery website: https://www.tigerstrikesasteroid.com/brooklyn.
# INFO     [Agent]   🦾 [ACTION 1/1] go_to_url: url: https://www.tigerstrikesasteroid.com/brooklyn, new_tab: False
# INFO     [tools] 🔗 Navigated to https://www.tigerstrikesasteroid.com/brooklyn
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 4:
# INFO     [Agent]   ⚠️ Eval: Failed to navigate to the specified URL, as the page returned a 'not found' error. Verdict: Failure
# INFO     [Agent]   🎯 Next goal: Navigate to the homepage of Tiger Strikes Asteroid by clicking the 'clicking here' link to find a working page and then look for exhibition information. I will also update the todo.md to reflect the current status.
# INFO     [Agent]   🦾 [ACTION 1/2] replace_file_str: file_name: todo.md, old_str: - [ ] Navigate to https://www.tigerstrikesasteroid.com/brooklyn, new_str: - [x
# INFO     [tools] 💾 Successfully replaced all occurrences of "- [ ] Navigate to https://www.tigerstrikesasteroid.com/brooklyn" with "- [x] Navigate to https://www.tigerstrikesasteroid.com/brooklyn (Page not found, attempting to navigate to homepage)" in file todo.md
# INFO     [Agent]   🦾 [ACTION 2/2] click_element_by_index: index: 14, while_holding_ctrl: False
# INFO     [tools] 🖱️ Clicked element with index 14
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 5:
# INFO     [Agent]   👍 Eval: Successfully navigated to the homepage of Tiger Strikes Asteroid. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Click on the 'Exhibitions' link to find details about current and upcoming exhibitions.
# INFO     [Agent]   🦾 [ACTION 1/1] click_element_by_index: index: 3, while_holding_ctrl: False
# INFO     [tools] 🖱️ Clicked element with index 3
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 6:
# INFO     [Agent]   👍 Eval: Successfully clicked on the 'Exhibitions' link. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Click on the 'Current' exhibitions link to view current exhibitions and look for 2025 events.
# INFO     [Agent]   🦾 [ACTION 1/1] click_element_by_index: index: 4, while_holding_ctrl: False
# ERROR    [cdp_use.client] CDP Error for request 188: {'code': -32000, 'message': 'Could not compute box model.'}
# WARNING  [BrowserSession] No visible quad found, using first quad
# ERROR    [cdp_use.client] CDP Error for request 191: {'code': -32000, 'message': 'Node does not have a layout object'}
# INFO     [tools] 🖱️ Clicked element with index 4
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 7:
# INFO     [Agent]   👍 Eval: Successfully clicked on the 'Current' exhibitions link. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Scroll down the page to find more current or upcoming exhibitions for 2025.
# INFO     [Agent]   🦾 [ACTION 1/1] scroll: down: True, num_pages: 1.0, frame_element_index: None
# INFO     [tools] 🔍 Scrolled down the page by one page
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 8:
# INFO     [Agent]   👍 Eval: Successfully scrolled down the page. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Continue scrolling down the page to find more current or upcoming exhibitions for 2025.
# INFO     [Agent]   🦾 [ACTION 1/1] scroll: down: True, num_pages: 1.0, frame_element_index: None
# INFO     [tools] 🔍 Scrolled down the page by one page
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 9:
# INFO     [Agent]   👍 Eval: Successfully scrolled down the page. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Extract the event details for 'NY / TNT Resident: Meena Hasan / Jan - Jun 2025' using `extract_structured_data`.
# INFO     [Agent]   🦾 [ACTION 1/1] extract_structured_data: query: Extract the event title, opening date, opening time, and exhibiting artist(s) for the even...
# INFO     [tools] 📄 <url>
# https://www.tigerstrikesasteroid.com/
# </url>
# <query>
# Extract the event title, opening date, opening time, and exhibiting artist(s) for the event 'NY / TNT Resident: Meena Hasan / Jan - Jun 2025'.
# </query>
# <result>
# Event Title: NY / TNT Resident: Meena Hasan / Jan - Jun 2025
# Opening Date: Jan - Jun 2025
# Opening Time: Not available
# Exhibiting Artist(s): Meena Hasan
# </result>
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 10:
# INFO     [Agent]   👍 Eval: Successfully extracted the event details for 'NY / TNT Resident: Meena Hasan / Jan - Jun 2025'. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Format the extracted event data into a JSON object, append it to `events.json`, update `results.md` with a markdown summary, and mark the task in `todo.md` as complete.
# INFO     [Agent]   🦾 [ACTION 1/1] read_file: file_name: events.json
# INFO     [tools] 💾 Read from file events.json.
# <content>
# []
# </content>
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 11:
# INFO     [Agent]   👍 Eval: Successfully read the content of `events.json`. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Format the extracted event data into a JSON object, append it to `events.json`, update `results.md` with a markdown summary, and mark the task in `todo.md` as complete.
# INFO     [Agent]   🦾 [ACTION 1/3] write_file: file_name: events.json, content: [\n  \n    gallery_name: Tiger Strikes Asteroid,\n    address: Not available
# INFO     [tools] 💾 Data written to file events.json successfully.
# INFO     [Agent]   🦾 [ACTION 2/3] write_file: file_name: results.md, content: \n## Tiger Strikes Asteroid\n- **Event Name:** NY / TNT Resident: Meena Hasan ...
# INFO     [tools] 💾 Data appended to file results.md successfully.
# INFO     [Agent]   🦾 [ACTION 3/3] replace_file_str: file_name: todo.md, old_str: - [ ] Extract event details (title, date, time, artist, source_url) for 202...
# INFO     [tools] 💾 Successfully replaced all occurrences of "- [ ] Extract event details (title, date, time, artist, source_url) for 2025 events." with "- [x] Extract event details (title, date, time, artist, source_url) for 2025 events." in file todo.md
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 12:
# INFO     [Agent]   👍 Eval: Successfully extracted event details and updated files. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Navigate to the next gallery website: https://www.bushwickgallery.com.
# INFO     [Agent]   🦾 [ACTION 1/1] go_to_url: url: https://www.bushwickgallery.com, new_tab: False
# ERROR    [cdp_use.client] CDP Error for request 390: {'code': -32000, 'message': 'Not attached to an active page'}
# INFO     [tools] 🔗 Navigated to https://www.bushwickgallery.com
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 13:
# INFO     [Agent]   👍 Eval: Successfully navigated to https://www.bushwickgallery.com. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Accept the cookie consent by clicking the 'Accept' button to dismiss the pop-up.
# INFO     [Agent]   🦾 [ACTION 1/1] click_element_by_index: index: 2, while_holding_ctrl: None
# INFO     [tools] 🖱️ Clicked element with index 2
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 14:
# INFO     [Agent]   ⚠️ Eval: Failed to accept cookie consent as the 'Accept' button was not found. Verdict: Failure
# INFO     [Agent]   🎯 Next goal: Click on the 'EXHIBITIONS' link to find details about current and upcoming exhibitions.
# INFO     [Agent]   🦾 [ACTION 1/1] click_element_by_index: index: 4, while_holding_ctrl: None
# INFO     [tools] 🖱️ Clicked element with index 4
# Error polling for token:
# WARNING  [service] Event send timed out after 10 seconds: ?▶ CreateAgentStepEvent#81c9 🏃
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 15:
# INFO     [Agent]   👍 Eval: Successfully clicked on the 'EXHIBITIONS' link. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Extract the event title, opening date, opening time, and exhibiting artist(s) for 'November 2025: Vivid Force: The Power of Bold Color' using `extract_structured_data`.
# INFO     [Agent]   🦾 [ACTION 1/1] extract_structured_data: query: Extract the event title, exhibition dates, opening reception date and time, and exhibiting...
# INFO     [tools] 📄 <url>
# https://bushwickgallery.com/exhibitions-calendar/
# </url>
# <query>
# Extract the event title, exhibition dates, opening reception date and time, and exhibiting artist(s) for the event 'November 2025: Vivid Force: The Power of Bold Color'. Also, extract the gallery name and address if visible.
# </query>
# <result>
# Event Title: November 2025: Vivid Force: The Power of Bold Color
# Exhibition Dates: November 13 – November 20
# Opening Reception Date and Time: Thursday, November 13 / 6PM – 8PM
# Exhibiting Artist(s): David Bender, Zeynep Solakoğlu, Sario De Nola, Kajal Zaveri, Gina Keatley, Matt Furman, Ebelle Shum, Jovan Stockhammer, April Baez, Cole Levi-Crouch, WWHHIITTEEDDEEEERR, Sam Price, Peiyang (Camille) Li, Tibor Matijas, Marc Mauro
# Gallery Name: Bushwick Gallery
# Gallery Address: 22 Fayette Street, Bushwick, Brooklyn, NY
# </result>
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 16:
# INFO     [Agent]   👍 Eval: Successfully extracted the event details for 'November 2025: Vivid Force: The Power of Bold Color' from Bushwick Gallery. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Format the extracted event data into a JSON object, append it to `events.json`, update `results.md` with a markdown summary, and mark the task in `todo.md` as complete.
# INFO     [Agent]   🦾 [ACTION 1/1] read_file: file_name: events.json
# INFO     [tools] 💾 Read from file events.json.
# <content>
# [
#   {
#     "gallery_name": "Tiger Strikes Asteroid",
#     "address": "Not available",
#     "event_name": "NY / TNT Resident: Meena Hasan / Jan - Jun 2025",
#     "opening_date": "Jan - Jun 2025",
#     "opening_time": "Not available",
#     "artist": "Meena Hasan",
#     "source_url": "https://www.tigerstrikesasteroid.com/"
#   }
# ]
#
# </content>
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 17:
# INFO     [Agent]   👍 Eval: Successfully read the content of `events.json`. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Format the extracted event data into a JSON object, append it to `events.json`, update `results.md` with a markdown summary, and mark the task in `todo.md` as complete.
# INFO     [Agent]   🦾 [ACTION 1/3] write_file: file_name: events.json, content: [\n  \n    gallery_name: Tiger Strikes Asteroid,\n    address: Not available
# INFO     [tools] 💾 Data written to file events.json successfully.
# INFO     [Agent]   🦾 [ACTION 2/3] write_file: file_name: results.md, content: \n## Bushwick Gallery\n- **Event Name:** November 2025: Vivid Force: The Power...
# INFO     [tools] 💾 Data appended to file results.md successfully.
# INFO     [Agent]   🦾 [ACTION 3/3] replace_file_str: file_name: todo.md, old_str: - [ ] Extract event details (title, date, time, artist, source_url) for 202...
# INFO     [tools] 💾 Successfully replaced all occurrences of "- [ ] Extract event details (title, date, time, artist, source_url) for 2025 events." with "- [x] Extract event details (title, date, time, artist, source_url) for 2025 events." in file todo.md
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 18:
# INFO     [Agent]   👍 Eval: Successfully extracted event details and updated files. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Navigate to the next gallery website: https://www.brooklynartcave.com/events.
# INFO     [Agent]   🦾 [ACTION 1/1] go_to_url: url: https://www.brooklynartcave.com/events, new_tab: False
# INFO     [tools] 🔗 Navigated to https://www.brooklynartcave.com/events
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 19:
# INFO     [Agent]   👍 Eval: Successfully navigated to https://www.brooklynartcave.com/events. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Scroll down the page to check for any events listed on the calendar for November 2025 or later in 2025.
# INFO     [Agent]   🦾 [ACTION 1/1] scroll: down: True, num_pages: 1.0, frame_element_index: None
# INFO     [tools] 🔍 Scrolled down the page by one page
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 20:
# INFO     [Agent]   👍 Eval: Successfully scrolled down the page. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Continue scrolling down the page to find more current or upcoming exhibitions for 2025.
# INFO     [Agent]   🦾 [ACTION 1/1] scroll: down: True, num_pages: 1.0, frame_element_index: None
# INFO     [tools] 🔍 Scrolled down the page by one page
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 21:
# INFO     [Agent]   👍 Eval: Successfully scrolled down the page. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Continue scrolling down the page to find more current or upcoming exhibitions for 2025.
# INFO     [Agent]   🦾 [ACTION 1/1] scroll: down: True, num_pages: 1.0, frame_element_index: None
# INFO     [tools] 🔍 Scrolled down the page by one page
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 22:
# INFO     [Agent]   👍 Eval: Successfully scrolled down the page. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Mark the task for Brooklyn Art Cave in `todo.md` as complete, indicating no 2025 events were found, and then proceed to the next task of consolidating the extracted data.
# INFO     [Agent]   🦾 [ACTION 1/1] replace_file_str: file_name: todo.md, old_str: - [ ] Extract event details (title, date, time, artist, source_url) for 202...
# INFO     [tools] 💾 Successfully replaced all occurrences of "- [ ] Extract event details (title, date, time, artist, source_url) for 2025 events." with "- [x] Extract event details (title, date, time, artist, source_url) for 2025 events. (No 2025 events found for Brooklyn Art Cave)" in file todo.md
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 23:
# INFO     [Agent]   👍 Eval: Successfully marked the task for Brooklyn Art Cave as complete in `todo.md`, indicating no 2025 events were found. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Read the `events.json` file to confirm its content, then read `results.md` to prepare the final markdown summary, and finally call `done` with the collected data.
# INFO     [Agent]   🦾 [ACTION 1/1] read_file: file_name: events.json
# INFO     [tools] 💾 Read from file events.json.
# <content>
# [
#   {
#     "gallery_name": "Tiger Strikes Asteroid",
#     "address": "Not available",
#     "event_name": "NY / TNT Resident: Meena Hasan / Jan - Jun 2025",
#     "opening_date": "Jan - Jun 2025",
#     "opening_time": "Not available",
#     "artist": "Meena Hasan",
#     "source_url": "https://www.tigerstrikesasteroid.com/"
#   },
#   {
#     "gallery_name": "Bushwick Gallery",
#     "address": "22 Fayette Street, Bushwick, Brooklyn, NY",
#     "event_name": "November 2025: Vivid Force: The Power of Bold Color",
#     "opening_date": "November 13 – November 20",
#     "opening_time": "Thursday, November 13 / 6PM – 8PM",
#     "artist": "David Bender, Zeynep Solakoğlu, Sario De Nola, Kajal Zaveri, Gina Keatley, Matt Furman, Ebelle Shum, Jovan Stockhammer, April Baez, Cole Levi-Crouch, WWHHIITTEEDDEEEERR, Sam Price, Peiyang (Camille) Li, Tibor Matijas, Marc Mauro",
#     "source_url": "https://bushwickgallery.com/exhibitions-calendar/"
#   }
# ]
#
# </content>
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 24:
# INFO     [Agent]   👍 Eval: Successfully read the content of `events.json`. Verdict: Success
# INFO     [Agent]   🎯 Next goal: Read the `results.md` file to prepare the final markdown summary, and then call `done` with the collected data.
# INFO     [Agent]   🦾 [ACTION 1/1] read_file: file_name: results.md
# INFO     [tools] 💾 Read from file results.md.
# <content>
# # Art Gallery Exhibition Collection Results
#
#
#
# ## Tiger Strikes Asteroid
# - **Event Name:** NY / TNT Resident: Meena Hasan / Jan - Jun 2025
# - **Opening Date:** Jan - Jun 2025
# - **Opening Time:** Not available
# - **Artist:** Meena Hasan
# - **Source URL:** https://www.tigerstrikesasteroid.com/
#
#
#
# ## Bushwick Gallery
# - **Event Name:** November 2025: Vivid Force: The Power of Bold Color
# - **Exhibition Dates:** November 13 – November 20
# - **Opening Reception:** Thursday, November 13 / 6PM – 8PM
# - **Artist(s):** David Bender, Zeynep Solakoğlu, Sario De Nola, Kajal Zaveri, Gina Keatley, Matt Furman, Ebelle Shum, Jovan Stockhammer, April Baez, Cole Levi-Crouch, WWHHIITTEEDDEEEERR, Sam Price, Peiyang (Camille) Li, Tibor Matijas, Marc Mauro
# - **Address:** 22 Fayette Street, Bushwick, Brooklyn, NY
# - **Source URL:** https://bushwickgallery.com/exhibitions-calendar/
#
#
# </content>
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 25:
# INFO     [Agent]   👍 Eval: Successfully read the content of `results.md` and `events.json`. Verdict: Success
# INFO     [Agent]   🎯 Next goal: The task is complete. I will now call the `done` action to submit the results.
# INFO     [Agent]   🦾 [ACTION 1/1] text='# Art Gallery Exhibition Collection Results\n\n## Tiger Strikes Asteroid\n- **Event Name:** NY / TNT Resident: Meena...
# INFO     [Agent]
# 📄  Final Result:
# # Art Gallery Exhibition Collection Results
#
# ## Tiger Strikes Asteroid
# - **Event Name:** NY / TNT Resident: Meena Hasan / Jan - Jun 2025
# - **Opening Date:** Jan - Jun 2025
# - **Opening Time:** Not available
# - **Artist:** Meena Hasan
# - **Source URL:** https://www.tigerstrikesasteroid.com/
#
#
#
# ## Bushwick Gallery
# - **Event Name:** November 2025: Vivid Force: The Power of Bold Color
# - **Exhibition Dates:** November 13 – November 20
# - **Opening Reception:** Thursday, November 13 / 6PM – 8PM
# - **Artist(s):** David Bender, Zeynep Solakoğlu, Sario De Nola, Kajal Zaveri, Gina Keatley, Matt Furman, Ebelle Shum, Jovan Stockhammer, April Baez, Cole Levi-Crouch, WWHHIITTEEDDEEEERR, Sam Price, Peiyang (Camille) Li, Tibor Matijas, Marc Mauro
# - **Address:** 22 Fayette Street, Bushwick, Brooklyn, NY
# - **Source URL:** https://bushwickgallery.com/exhibitions-calendar/
#
#
# ## Brooklyn Art Cave
# No 2025 events were found for Brooklyn Art Cave.
#
# Attachments:
#
# events.json:
# [
#   {
#     "gallery_name": "Tiger Strikes Asteroid",
#     "address": "Not available",
#     "event_name": "NY / TNT Resident: Meena Hasan / Jan - Jun 2025",
#     "opening_date": "Jan - Jun 2025",
#     "opening_time": "Not available",
#     "artist": "Meena Hasan",
#     "source_url": "https://www.tigerstrikesasteroid.com/"
#   },
#   {
#     "gallery_name": "Bushwick Gallery",
#     "address": "22 Fayette Street, Bushwick, Brooklyn, NY",
#     "event_name": "November 2025: Vivid Force: The Power of Bold Color",
#     "opening_date": "November 13 – November 20",
#     "opening_time": "Thursday, November 13 / 6PM – 8PM",
#     "artist": "David Bender, Zeynep Solakoğlu, Sario De Nola, Kajal Zaveri, Gina Keatley, Matt Furman, Ebelle Shum, Jovan Stockhammer, April Baez, Cole Levi-Crouch, WWHHIITTEEDDEEEERR, Sam Price, Peiyang (Camille) Li, Tibor Matijas, Marc Mauro",
#     "source_url": "https://bushwickgallery.com/exhibitions-calendar/"
#   }
# ]
#
#
# results.md:
# # Art Gallery Exhibition Collection Results
#
#
#
# ## Tiger Strikes Asteroid
# - **Event Name:** NY / TNT Resident: Meena Hasan / Jan - Jun 2025
# - **Opening Date:** Jan - Jun 2025
# - **Opening Time:** Not available
# - **Artist:** Meena Hasan
# - **Source URL:** https://www.tigerstrikesasteroid.com/
#
#
#
# ## Bushwick Gallery
# - **Event Name:** November 2025: Vivid Force: The Power of Bold Color
# - **Exhibition Dates:** November 13 – November 20
# - **Opening Reception:** Thursday, November 13 / 6PM – 8PM
# - **Artist(s):** David Bender, Zeynep Solakoğlu, Sario De Nola, Kajal Zaveri, Gina Keatley, Matt Furman, Ebelle Shum, Jovan Stockhammer, April Baez, Cole Levi-Crouch, WWHHIITTEEDDEEEERR, Sam Price, Peiyang (Camille) Li, Tibor Matijas, Marc Mauro
# - **Address:** 22 Fayette Street, Bushwick, Brooklyn, NY
# - **Source URL:** https://bushwickgallery.com/exhibitions-calendar/
#
#
#
#
# INFO     [Agent] 👉 Attachment 1: /var/folders/49/6ydqkbq172ngzt6p49xfm6b00000gn/T/browser_use_agent_0691a117-ae2b-7bdb-8000-8b5d7a45601d_1763316090/browseruse_agent_data/events.json
# INFO     [Agent] 👉 Attachment 2: /var/folders/49/6ydqkbq172ngzt6p49xfm6b00000gn/T/browser_use_agent_0691a117-ae2b-7bdb-8000-8b5d7a45601d_1763316090/browseruse_agent_data/results.md
# INFO     [Agent] ✅ Task completed successfully
# WARNING  [cdp_use.client] WebSocket connection closed: no close frame received or sent
# ✅ Results from ['https://www.tigerstrikesasteroid.com/brooklyn', 'https://www.bushwickgallery.com', 'https://www.brooklynartcave.com/events'] saved.
